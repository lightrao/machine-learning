# %% [markdown]
# # Seaborn
#
# Seaborn is a visualization library that sits on top of matplotlib, making it nicer to look at and adding some extra capabilities too.
#
# Let's start by loading up a real dataset on 2019 model-year vehicles, and take a closer look at the data we're dealing with.

# %%
# %matplotlib inline
import pandas as pd

# df = pd.read_csv("http://media.sundog-soft.com/SelfDriving/FuelEfficiency.csv")
df = pd.read_csv("./myFile/FuelEfficiency.csv")
print(len(df))
df.head(51)
# Out:
# 718
#                Mfr Name                      Carline  Eng Displ  Cylinders  \
# 0          aston martin                   Vantage V8        4.0          8
# 1   Volkswagen Group of                       Chiron        8.0         16
# 2        General Motors                     CORVETTE        6.2          8
# 3        General Motors                     CORVETTE        6.2          8
# 4        General Motors                     CORVETTE        6.2          8
# 5        General Motors                     CORVETTE        6.2          8
# 6        General Motors                     CORVETTE        6.2          8
# 7        General Motors                     CORVETTE        6.2          8
# 8               Ferrari                      488 gtb        3.9          8
# 9               Ferrari                      488 gtb        3.9          8
# 10              Ferrari                    488 Pista        3.9          8
# 11              Ferrari             488 Pista Spider        3.9          8
# 12              Ferrari                   488 Spider        3.9          8
# 13              Ferrari                   488 Spider        3.9          8
# 14              Ferrari                812 Superfast        6.5         12
# 15           FCA US LLC                   124 Spider        1.4          4
# 16           FCA US LLC                   124 Spider        1.4          4
# 17  Jaguar Land Rover L           F-TYPE Convertible        2.0          4
# 18  Jaguar Land Rover L           F-TYPE Convertible        3.0          6
# 19  Jaguar Land Rover L    F-TYPE Convertible Manual        3.0          6
# 20  Jaguar Land Rover L                 F-TYPE Coupe        2.0          4
# 21  Jaguar Land Rover L                 F-TYPE Coupe        3.0          6
# 22  Jaguar Land Rover L          F-TYPE Coupe Manual        3.0          6
# 23  Jaguar Land Rover L     F-TYPE S AWD Convertible        3.0          6
# 24  Jaguar Land Rover L           F-TYPE S AWD Coupe        3.0          6
# 25  Jaguar Land Rover L         F-TYPE S Convertible        3.0          6
# 26  Jaguar Land Rover L  F-TYPE S Convertible Manual        3.0          6
# 27  Jaguar Land Rover L               F-TYPE S Coupe        3.0          6
# 28  Jaguar Land Rover L        F-TYPE S Coupe Manual        3.0          6
# 29  Volkswagen Group of              Aventador Coupe        6.5         12
# 30  Volkswagen Group of           Aventador Roadster        6.5         12
# 31                MAZDA                         MX-5        2.0          4
# 32                MAZDA                         MX-5        2.0          4
# 33               Nissan                         370Z        3.7          6
# 34               Nissan                         370Z        3.7          6
# 35               Nissan                370Z Roadster        3.7          6
# 36              Porsche                   911 GT2 RS        3.8          6
# 37              Porsche                      911 GT3        4.0          6
# 38              Porsche                      911 GT3        4.0          6
# 39              Porsche              911 GT3 Touring        4.0          6
# 40              Porsche                      Boxster        2.0          4
# 41              Porsche                      Boxster        2.0          4
# 42              Porsche                  Boxster GTS        2.5          4
# 43              Porsche                  Boxster GTS        2.5          4
# 44              Porsche                    Boxster S        2.5          4
# 45              Porsche                    Boxster S        2.5          4
# 46              Porsche                       Cayman        2.0          4
# 47              Porsche                       Cayman        2.0          4
# 48              Porsche                   Cayman GTS        2.5          4
# 49              Porsche                   Cayman GTS        2.5          4
# 50              Porsche                     Cayman S        2.5          4
#
#    Transmission  CityMPG  HwyMPG  CombMPG  # Gears
# 0      Auto(S8)       18      25       21        8
# 1   Auto(AM-S7)        9      14       11        7
# 2      Auto(S8)       12      20       15        8
# 3      Auto(S8)       15      25       18        8
# 4      Auto(S8)       14      23       17        8
# 5    Manual(M7)       13      19       15        7
# 6    Manual(M7)       15      22       17        7
# 7    Manual(M7)       16      25       19        7
# 8     Auto(AM7)       16      22       18        7
# 9     Auto(AM7)       15      22       18        7
# 10    Auto(AM7)       15      20       17        7
# 11    Auto(AM7)       15      19       17        7
# 12    Auto(AM7)       16      22       18        7
# 13    Auto(AM7)       15      22       18        7
# 14    Auto(AM7)       12      16       13        7
# 15     Auto(A6)       25      36       29        6
# 16   Manual(M6)       26      35       30        6
# 17     Auto(S8)       23      30       26        8
# 18     Auto(S8)       20      28       23        8
# 19   Manual(M6)       16      24       19        6
# 20     Auto(S8)       23      30       26        8
# 21     Auto(S8)       20      28       23        8
# 22   Manual(M6)       16      24       19        6
# 23     Auto(S8)       18      26       21        8
# 24     Auto(S8)       18      26       21        8
# 25     Auto(S8)       19      27       22        8
# 26   Manual(M6)       15      24       18        6
# 27     Auto(S8)       19      27       22        8
# 28   Manual(M6)       15      24       18        6
# 29  Auto(AM-S7)        9      15       11        7
# 30  Auto(AM-S7)        9      15       11        7
# 31     Auto(S6)       26      35       30        6
# 32   Manual(M6)       26      34       29        6
# 33     Auto(S7)       19      26       22        7
# 34   Manual(M6)       17      26       20        6
# 35     Auto(S7)       18      25       21        7
# 36  Auto(AM-S7)       15      21       17        7
# 37  Auto(AM-S7)       15      20       17        7
# 38   Manual(M6)       13      21       16        6
# 39   Manual(M6)       14      21       17        6
# 40  Auto(AM-S7)       22      29       25        7
# 41   Manual(M6)       21      28       24        6
# 42  Auto(AM-S7)       20      26       22        7
# 43   Manual(M6)       19      25       21        6
# 44  Auto(AM-S7)       21      28       24        7
# 45   Manual(M6)       20      26       22        6
# 46  Auto(AM-S7)       22      29       25        7
# 47   Manual(M6)       21      28       24        6
# 48  Auto(AM-S7)       20      26       22        7
# 49   Manual(M6)       19      25       21        6
# 50  Auto(AM-S7)       21      28       24        7

# %% [markdown]
# The table head consists of nine columns, each representing a different attribute of the 2019 model-year vehicles. Here is what each column means:
#
# - **Mfr Name**: This is the name of the manufacturer of the vehicle, such as Aston Martin, Volkswagen, or General Motors.
# - **Carline**: This is the name of the specific model of the vehicle, such as Vantage V8, Chiron, or Corvette.
# - **Eng Displ**: This is the engine displacement of the vehicle, measured in liters. It indicates the volume of space that the pistons sweep through in each cycle of the engine.
# - **Cylinders**: This is the number of cylinders in the engine of the vehicle. It indicates how many combustion chambers are available for generating power.
# - **Transmission**: This is the type of transmission system used by the vehicle, such as automatic or manual. It also indicates the number of gears or speeds available for changing the ratio of engine speed to wheel speed.
# - **CityMPG**: This is the estimated fuel economy of the vehicle in city driving conditions, measured in miles per gallon (MPG). It indicates how far the vehicle can travel on one gallon of fuel in urban areas with frequent stops and starts.
# - **HwyMPG**: This is the estimated fuel economy of the vehicle in highway driving conditions, measured in miles per gallon (MPG). It indicates how far the vehicle can travel on one gallon of fuel in rural areas with steady speeds and less traffic.
# - **CombMPG**: This is the estimated combined fuel economy of the vehicle in both city and highway driving conditions, measured in miles per gallon (MPG). It indicates how far the vehicle can travel on one gallon of fuel on average across different types of roads and driving patterns.
# - **# Gears**: This is the number of gears or speeds available in the transmission system of the vehicle. It indicates how many options the driver has for adjusting the engine speed to match the desired driving speed.

# %% [markdown]
# Plotting a histogram just using matplotlib to see the distribution by number of gears.

# %%
gear_counts = df["# Gears"].value_counts()
gear_counts.plot(kind="bar")
# Out:
# <Axes: xlabel='# Gears'>

# %% [markdown]
# We can load up Seaborn, and just call set() on it to change matplotlib's default settings to something more visually pleasing.

# %%
# ignore warning
import warnings

warnings.filterwarnings("ignore")

# Import the seaborn library, which is a data visualization library based on matplotlib
import seaborn as sns

# Set the default aesthetic parameters for the plots, such as the style, color, font, etc.
sns.set()

# %% [markdown]
# Now if we do the same plot command, it's a little more modern looking. Matplotlib is based on Matplot, and its visualization defaults are frankly showing their age.

# %%
gear_counts.plot(kind="bar")
# Out:
# <Axes: xlabel='# Gears'>

# %% [markdown]
# Seaborn includes many types of plots that matplotlib doens't offer. For example, "distplot" can be used to plot a histogram together with a smooth distribution of that histogram overlaid on it. Let's plot the distribution of MPG values on the vehicles in this database as an example:

# %%
# sns.distplot(df["CombMPG"])

# %%
sns.histplot(df["CombMPG"], kde=True, stat="density")
# Out:
# <Axes: xlabel='CombMPG', ylabel='Density'>

# %% [markdown]
# Something you encounter pretty often is a "pair plot" from Seaborn. This lets you visualize plots of every combination of various attributes together, so you can look for interesting patterns between features.
#
# As an example, let's classify cars by how many cylinders are in their engines, and look for relationships between cylinders, city MPG rating, Highway MPG rating, and combined MPG rating.

# %%
df2 = df[["Cylinders", "CityMPG", "HwyMPG", "CombMPG"]]
df2.head()
# Out:
#    Cylinders  CityMPG  HwyMPG  CombMPG
# 0          8       18      25       21
# 1         16        9      14       11
# 2          8       12      20       15
# 3          8       15      25       18
# 4          8       14      23       17

# %%
# see the average MPG values for each group of cylinders
df2.groupby("Cylinders").mean()
# Out:
#              CityMPG     HwyMPG    CombMPG
# Cylinders
# 3          25.071429  33.714286  28.357143
# 4          24.179567  31.585139  26.978328
# 6          18.460905  25.901235  21.164609
# 8          14.992126  21.842520  17.417323
# 12         11.800000  17.600000  13.700000
# 16          9.000000  14.000000  11.000000

# %%
# create a matrix of scatter plots and histograms for each pair of variables
sns.pairplot(df2, height=2.5)
# Seaborn currently has a bug with the hue parameter so we've omitted it

# %% [markdown]
# By studying the results above, you can see there is a relationship between number of cylinders and MPG, but MPG for 4-cylinder vehicles ranges really widely. There also appears to be a good linear relationship between the different ways of measuring MPG values, until you get into the higher MPG ratings.

# %% [markdown]
# Seaborn 1.9 also includes "scatterplot", which is exactly what it sounds like. It plots individual data points across two axes of your choosing, so you can see how your data is distributed across those dimensions.

# %%
# There is a strong negative correlation between engine displacement and combined MPG,
# as larger engines usually consume more fuel and produce more power
sns.scatterplot(x="Eng Displ", y="CombMPG", data=df)
# Out:
# <Axes: xlabel='Eng Displ', ylabel='CombMPG'>

# %% [markdown]
# Seaborn also offers a "jointplot", which combines a scatterplot with histograms on both axes. This lets you visualize both the individual data points and the distribution across both dimensions at the same time.

# %%
sns.jointplot(x="Eng Displ", y="CombMPG", data=df)

# %% [markdown]
# The "lmplot" is a scatterplot, but with a linear regression line computed and overlaid onto the data.

# %%
sns.lmplot(x="Eng Displ", y="CombMPG", data=df)

# %% [markdown]
# Next, let's look at a "box plot." This is what's called a "box and whiskers" plot, which is useful for visualizing typical values for a given category without getting distracted by outliers. Each box represents the range between the first and third quartiles of the data, with a line representing the median value. The "whiskers" that extend from the box represent the spread of the remainder of the data, apart from clear outliers that are plotted as individual points outside of the whiskers.
#
# As an example, let's look at box plots for each vehicle manufacturer, visualizing the miles-per-gallon ratings across the vehicles they produce. This lets us look at the spread of MPG ratings across all the vehicles each manufacturer offers.
#
# There are a lot of manufacturers, so to make the resulting graph readable we'll increase Seaborn's default figure size, and also use set_xticklabels to rotate the labels 45 degrees.

# %%
# This line sets the default aesthetic parameters for the plot, such as the font size,
# color palette, and figure size. The `rc` argument is a dictionary that contains the
# parameter names and values. In this case, the `figure.figsize` parameter is set to `(15, 5)`,
# which means that the figure will have a width of 15 inches and a height of 5 inches.
sns.set(rc={"figure.figsize": (15, 5)})

# This line creates a box plot of the combined MPG variable for each manufacturer name
# from the dataframe. The `x` argument specifies the categorical variable to be plotted on
# the x-axis, which is the manufacturer name. The `y` argument specifies the numerical variable
# to be plotted on the y-axis, which is the combined MPG. The `data` argument specifies the dataframe
# that contains the data. The function returns an object called `ax`,
# which is an axes object that contains the plot and its elements.
ax = sns.boxplot(x="Mfr Name", y="CombMPG", data=df)

# This line modifies the labels of the x-axis ticks, which are the names of the car brands.
# The `set_xticklabels` method sets the labels of the ticks, and takes a list of strings as an argument.
# The `get_xticklabels` method returns a list of strings that are the current labels of the ticks.
# The `rotation` argument specifies the angle of rotation for the labels, in degrees. In this case,
# the labels are rotated by 45 degrees, which makes them more readable and avoids overlapping.
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Porsche'),
#  Text(9, 0, 'BMW'),
#  Text(10, 0, 'Subaru'),
#  Text(11, 0, 'Toyota'),
#  Text(12, 0, 'Ford Motor Company'),
#  Text(13, 0, 'Mercedes-Benz'),
#  Text(14, 0, 'Honda'),
#  Text(15, 0, 'Hyundai'),
#  Text(16, 0, 'Rolls-Royce'),
#  Text(17, 0, 'Volvo'),
#  Text(18, 0, 'Kia'),
#  Text(19, 0, 'Maserati'),
#  Text(20, 0, 'Mitsubishi Motors Co')]

# %% [markdown]
# Another way to visualize the same data is the "swarm plot." Instead of boxes and whiskers, it plots each individual data point - but does so in such way that groups them together based on their distribution.
#
# A swarm plot consists of a series of points that represent each observation in the data. The points are arranged along the categorical axis, such as the manufacturer name, and spread along the numerical axis, such as the combined MPG, to avoid overlapping.
#
# It makes more sense when you look at it:

# %%
ax = sns.swarmplot(x="Mfr Name", y="CombMPG", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Porsche'),
#  Text(9, 0, 'BMW'),
#  Text(10, 0, 'Subaru'),
#  Text(11, 0, 'Toyota'),
#  Text(12, 0, 'Ford Motor Company'),
#  Text(13, 0, 'Mercedes-Benz'),
#  Text(14, 0, 'Honda'),
#  Text(15, 0, 'Hyundai'),
#  Text(16, 0, 'Rolls-Royce'),
#  Text(17, 0, 'Volvo'),
#  Text(18, 0, 'Kia'),
#  Text(19, 0, 'Maserati'),
#  Text(20, 0, 'Mitsubishi Motors Co')]

# %% [markdown]
# Another tool is the "count plot." This is basically the same thing as a histogram, but for categorical data. It lets you count up how many times each given category on the X axis occurs in your data, and plot it. So for example, we can see that General Motors offers more vehicle models than anyone else, with BMW not far behind.
#
# A count plot consists of a series of bars that represent the count of each category in the categorical variable, such as the manufacturer name.

# %%
ax = sns.countplot(x="Mfr Name", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Porsche'),
#  Text(9, 0, 'BMW'),
#  Text(10, 0, 'Subaru'),
#  Text(11, 0, 'Toyota'),
#  Text(12, 0, 'Ford Motor Company'),
#  Text(13, 0, 'Mercedes-Benz'),
#  Text(14, 0, 'Honda'),
#  Text(15, 0, 'Hyundai'),
#  Text(16, 0, 'Rolls-Royce'),
#  Text(17, 0, 'Volvo'),
#  Text(18, 0, 'Kia'),
#  Text(19, 0, 'Maserati'),
#  Text(20, 0, 'Mitsubishi Motors Co')]

# %%
ax = sns.countplot(x="Cylinders", data=df)

# %% [markdown]
# Finally, let's look at a heat-map in Seaborn. A heat map allows you to plot tabular, 2D data of some sort, with colors representing the individual values in each cell of the 2D table.
#
# In this example, we'll create a pivot table from our original dataframe, to create a 2D table that contains the average MPG ratings for every combination of number of cylinders and engine displacement.
#
# The resulting heatmap shows all of the engine displacement values along the X axis, and all of the cylinder values along the Y axis. For each cell of the table, the actual average MPG rating for that combination of cylinders and engine displacement is represented not as a number, but as a color that ranges from dark for small values, and light for larger values.
#
# And, this does allow you visualize a clear trend where things get progressively darker as we move from the top-left of the graph to the bottom-right. Which makes sense; higher MPG ratings are associated with lower numbers of cylinders, and lower engine displacment values. By the time we get to an 8-liter 16-cylinder engine, the average MPG is at its worst of about 12, represented by the color black.
#
# This particular graph has a lot of missing data, but the heatmap deals with that gracefully. A 3-cylinder 8-liter engine simply does not exist!

# %%
# The pivot table shows the mean value of the combined MPG for each group of cylinders and engine displacement.
# The rows represent the different numbers of cylinders. The columns represent the different values of engine displacement.
# The cells show the mean combined MPG for each combination, or NaN if there is no data for that combination.
df2 = df.pivot_table(
    index="Cylinders", columns="Eng Displ", values="CombMPG", aggfunc="mean"
)
print(df2)
sns.heatmap(df2)
# Out:
# Eng Displ        1.4        1.5    1.6        1.8        2.0        2.3  \
# Cylinders
# 3                NaN  28.357143    NaN        NaN        NaN        NaN
# 4          31.133333  32.785714  32.32  30.818182  26.085106  23.142857
# 6                NaN        NaN    NaN        NaN        NaN        NaN
# 8                NaN        NaN    NaN        NaN        NaN        NaN
# 12               NaN        NaN    NaN        NaN        NaN        NaN
# 16               NaN        NaN    NaN        NaN        NaN        NaN
#
# Eng Displ        2.4        2.5   2.8   2.9  ...   5.2        5.3   5.6  \
# Cylinders                                    ...
# 3                NaN        NaN   NaN   NaN  ...   NaN        NaN   NaN
# 4          25.208333  25.323529  21.8   NaN  ...   NaN        NaN   NaN
# 6                NaN        NaN   NaN  19.5  ...   NaN        NaN   NaN
# 8                NaN        NaN   NaN   NaN  ...   NaN  17.346154  17.0
# 12               NaN        NaN   NaN   NaN  ...  17.0        NaN   NaN
# 16               NaN        NaN   NaN   NaN  ...   NaN        NaN   NaN
#
# Eng Displ    5.7        6.2   6.3        6.4        6.5   6.6   8.0
# Cylinders
# 3            NaN        NaN   NaN        NaN        NaN   NaN   NaN
# 4            NaN        NaN   NaN        NaN        NaN   NaN   NaN
# 6            NaN        NaN   NaN        NaN        NaN   NaN   NaN
# 8          16.75  16.851852   NaN  17.666667        NaN   NaN   NaN
# 12           NaN        NaN  13.0        NaN  11.666667  14.4   NaN
# 16           NaN        NaN   NaN        NaN        NaN   NaN  11.0
#
# [6 rows x 32 columns]
# <Axes: xlabel='Eng Displ', ylabel='Cylinders'>

# %% [markdown]
# ## Exercise
#
# Explore the relationship between the number of gears a car has, and its combined MPG rating. Visualize these two dimensions using a scatter plot, lmplot, jointplot, boxplot, and swarmplot. What conclusions can you draw?

# %%
sns.scatterplot(x="# Gears", y="CombMPG", data=df)
# Out:
# <Axes: xlabel='# Gears', ylabel='CombMPG'>

# %% [markdown]
# A scatterplot arranges itself into columns when you have ordinal data like the number of gears, but it tells us that there's a pretty wide range of MPG values for each type of gear box, although if you look at where the data points are clustered, you can sort of see a downward trend in MPG as the number of gears increases. But it's subtle.
#
# We also see that there's such a thing as a single gear car. These are "continuously variable transmission" cars, and we can see they typically have high MPG ratings and are therefore quite efficient.

# %%
sns.lmplot(x="# Gears", y="CombMPG", data=df)

# %% [markdown]
# The "lmplot" gives us a linear regression of our data overlaid on the graph, and this makes the overall trend of lower MPG's with more gears apparent. More gears isn't better when it comes to efficiency, it seems. We also see the error bars on that regression line, which tells us this trend is probably real and not just the result of randomness in the samples.

# %%
sns.jointplot(x="# Gears", y="CombMPG", data=df)

# %% [markdown]
# The jointplot gives us histograms on each axis, which provides some interesting insights. The most common gear configuration seems to be 8, with 6 closely behind. And MPG ratings seem to roughly follow a bell curve centered at around 22 or so.

# %%
sns.boxplot(x="# Gears", y="CombMPG", data=df)
# Out:
# <Axes: xlabel='# Gears', ylabel='CombMPG'>

# %% [markdown]
# The box plot shows us that the range of MPG values we see on each gearbox type aren't as crazily distributed as it seemed at first glance; many of the extreme values are in fact outliers that are best discarded when analyzing the trends. This makes the real relationships easier to see; those continuously variable transmissions with a single gear are really quite good at fuel efficiency (higher MPG's are more efficient). Between 5 and 8 things are roughly the same, but from 8-10 things decline markedly.

# %%
sns.swarmplot(x="# Gears", y="CombMPG", data=df)
# Out:
# <Axes: xlabel='# Gears', ylabel='CombMPG'>

# %% [markdown]
# The swarm plot makes it even more apparent that those high MPG outliers are in fact outliers on the 6-gear vehicles; the vast majority of 6-gear vehcles have less than 32 MPG. And the overall trend is perhaps easiest to visualize and understand in this representation.
#
# So, our final verdict: more gears result in worse fuel efficiency. Which strikes me as a little counter-intuitive! But, this is real data from the US Department of Energy for 2019 model year cars, and that's a real conclusion we've drawn, thanks to Seaborn!
